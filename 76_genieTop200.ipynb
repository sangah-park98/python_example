# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Computer.use_jedi = False
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
# 타겟 사이트 주소 만들기
'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230823&hh=18&rtm=Y&pg=1' # 1 ~ 50
'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230823&hh=18&rtm=Y&pg=2' # 51 ~ 100
'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230823&hh=18&rtm=Y&pg=3' # 101 ~ 150
'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230823&hh=18&rtm=Y&pg=4' # 151 ~ 200
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230823&hh=18&rtm=Y&pg='
for i in range(1, 5):
    targetSite = url + str(i)
    # targetSite = '{}{}'.format(url, i)
    print(targetSite)
# Out:
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230823&hh=18&rtm=Y&pg=1
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230823&hh=18&rtm=Y&pg=2
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230823&hh=18&rtm=Y&pg=3
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230823&hh=18&rtm=Y&pg=4

# %%
targetSite = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230823&hh=18&rtm=Y&pg=1'
request = requests.get(targetSite)
print(request)
html = request.text
print(html)
# Out:
# <Response [200]>
# <br>
# <br>
# <center>
# <br>
# <h2> <meta http-equiv="Content-Type" content="text/html;charset=UTF-8"> ì ììì²­ì´ ë³´ìì ì±ì ìí´ ì°¨ë¨ëììµëë¤. ë¹ì¬ ê³ ê°ì¼í°ë¡ ë¬¸ìí´ì£¼ì­ìì¤.<br><br>
# The security policy of the connection request is blocked. Contact your customer service representative.<br><br>
# ì§ëë®¤ì§ ê³ ê°ì¼í° 1577-5337<br><br>
# </h2>
# </center>
# <br>

# %%
html = request.text
# print(html)
soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# <br/>
# <br/>
# <center>
# <br/>
# <h2> <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/> ì ììì²­ì´ ë³´ìì ì±ì ìí´ ì°¨ë¨ëììµëë¤. ë¹ì¬ ê³ ê°ì¼í°ë¡ ë¬¸ìí´ì£¼ì­ìì¤.<br/><br/>
# The security policy of the connection request is blocked. Contact your customer service representative.<br/><br/>
# ì§ëë®¤ì§ ê³ ê°ì¼í° 1577-5337<br/><br/>
# </h2>
# </center>
# <br/>

# %%
targetSite = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230823&hh=18&rtm=Y&pg=1'
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko'}
request = requests.get(targetSite, headers=header)
print(request)
html = request.text
print(html)
# Out:
# <Response [200]>
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#
#
#
#
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <!--[if lte IE 6]><html dir="ltr" class="no-js ie6"><![endif]-->
# <!--[if lte IE 7]><html dir="ltr" class="no-js ie7"><![endif]-->
# <!--[if IE 8]><html dir="ltr" class="no-js ie8"><![endif]-->
# <!--[if IE 9]><html dir="ltr" class="no-js ie9"><![endif]-->
# <!--[if (gte IE 10)|!(IE)]><!--><html dir="ltr" class="no-js"><!--<![endif]-->
# <title>음악, 그리고 설레임 - 지니</title>
# <meta charset="utf-8" />
# <meta name="naver-site-verification" content="d17289f97c7f294985a9b0eb3649a45ac5ceeee2"/>
# <meta name="google-site-verification" content="-l7MNwwsDcn29Pnu00OagSrpDUPbjqLYoY08rhXLde8" />
#
# <meta name="description" content="가격은 가볍게, 추천은 확실하게! 최저가로 즐기는 프리미어 사운드! 국내 최초 실시간 TOP 200 차트" />
# <meta name="viewport" content="width=1200" />
# <meta property="og:url" content=""/>
# <meta property="og:type" content="website">
# ...

# %%
# 노래 제목 크롤링
titles = soup.findAll('a', {'class', 'title ellipsis'})
# print(titles)
for i in range(len(titles)):
    # print('{:3d}위 {}'.format(i+1, titles[i].text.strip()))
    # print('{:3d}위 {}'.format(i+1, titles[i].text.strip()))
    print('{:3d}위 {}'.format(i+1, titles[i].text.strip().split('\n')[0]))

# %%
# 아티스트 크롤링
artists = soup.findAll('a', {'class', 'artist ellipsis'})
# print(artists)

i = 1
for artist in artists[5:]:
    print('{:3d}위 {}'.format(i, artist.text.strip()))
    i += 1

# %%
for i in range(len(artists[5:])):
    print('{:3d}위 {}'.format(i+1, artists[i+5].text.split('\n')[0]))

# %%
for i in range(5, len(artists)):
    print('{:3d}위 {}'.format(i-4, artists[i].text.strip().split('\n')[0]))

# %%
# 4페이지를 크롤링해서 결과를 하나의 리스트에 모아준다.
genie = []
targetSite = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230823&hh=18&rtm=Y&pg=1'
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 5):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.findAll('a', {'class', 'title ellipsis'})
    artists = soup.findAll('a', {'class', 'artist ellipsis'})
    
    for j in range(50):
        genie.append(
            (artists[j+5].text.strip().split('\n'),
            titles[j].text.strip().split('\n')[0])
        )
# ------ for i
    
    # ------- for j
print(len(genie)) 
print(genie)
# Out:
# [(['NewJeans'], 'ETA'), (['정국'], 'Seven (Feat. Latto) (Clean Ver.)'), (['NewJeans'], 'Super Shy'), (['박재정'], '헤어지자 말해요'), (['IVE (아이브)'], 'I AM'), (['(여자)아이들'], '퀸카 (Queencard)'), (['NewJeans'], 'Hype boy'), (['우디 (Woody)'], '사막에서 꽃을 피우듯'), (['aespa'], 'Spicy'), (['LE SSERAFIM (르세라핌)'], '이브, 프시케 그리고 푸른 수염의 아내'), (['임영웅'], '사랑은 늘 도망가'), (['IVE (아이브)'], 'Kitsch'), (['AKMU (악뮤)'], 'Love Lee'), (['임영웅'], '우리들의 블루스'), (['임영웅'], '모래 알갱이'), (['Paul Blanco'], "Summer (Feat. BE'O (비오))"), (['임영웅'], '다시 만날 수 있을까'), (['전소미'], 'Fast Forward'), (['임영웅'], '이제 나만 믿어요'), (['임영웅'], '무지개'), (['NewJeans'], 'Ditto'), (['임영웅'], 'London Boy'), (['임영웅'], 'Polaroid'), (['임영웅'], '아버지'), (['윤하 (YOUNHA)'], '사건의 지평선'), (['임영웅'], 'A bientot'), (['임영웅'], '손이 참 곱던 그대'), (['임영웅'], '사랑해 진짜'), (['Lauv'], 'Steal The Show'), (['임영웅'], '연애편지'), (['임영웅'], '보금자리'), (['임영웅'], '인생찬가'), (['NewJeans'], 'New Jeans'), (['LE SSERAFIM (르세라핌)'], 'UNFORGIVEN (Feat. Nile Rodgers)'), (['IVE (아이브)'], 'After LIKE'), (['Charlie Puth'], 
# ...

# %%
print(dt.now())
for i in range(200):
    print('{:3d}위 {} - {}'.format(i+1, genie[i][0], genie[i][1]))
# Out:
# 2023-08-24 10:40:57.853684
#   1위 ['NewJeans'] - ETA
#   2위 ['정국'] - Seven (Feat. Latto) (Clean Ver.)
#   3위 ['NewJeans'] - Super Shy
#   4위 ['박재정'] - 헤어지자 말해요
#   5위 ['IVE (아이브)'] - I AM
#   6위 ['(여자)아이들'] - 퀸카 (Queencard)
#   7위 ['NewJeans'] - Hype boy
#   8위 ['우디 (Woody)'] - 사막에서 꽃을 피우듯
#   9위 ['aespa'] - Spicy
#  10위 ['LE SSERAFIM (르세라핌)'] - 이브, 프시케 그리고 푸른 수염의 아내
#  11위 ['임영웅'] - 사랑은 늘 도망가
#  12위 ['IVE (아이브)'] - Kitsch
#  13위 ['AKMU (악뮤)'] - Love Lee
#  14위 ['임영웅'] - 우리들의 블루스
#  15위 ['임영웅'] - 모래 알갱이
#  16위 ['Paul Blanco'] - Summer (Feat. BE'O (비오))
#  17위 ['임영웅'] - 다시 만날 수 있을까
#  18위 ['전소미'] - Fast Forward
#  19위 ['임영웅'] - 이제 나만 믿어요
#  20위 ['임영웅'] - 무지개
#  21위 ['NewJeans'] - Ditto
#  22위 ['임영웅'] - London Boy
#  23위 ['임영웅'] - Polaroid
#  24위 ['임영웅'] - 아버지
#  25위 ['윤하 (YOUNHA)'] - 사건의 지평선
#  26위 ['임영웅'] - A bientot
#  27위 ['임영웅'] - 손이 참 곱던 그대
#  28위 ['임영웅'] - 사랑해 진짜
#  29위 ['Lauv'] - Steal The Show
#  30위 ['임영웅'] - 연애편지
#  31위 ['임영웅'] - 보금자리
#  32위 ['임영웅'] - 인생찬가
# ...

# %%
with open('./output/genieTop100.txt', 'w', -1, 'utf-8') as file:
    file.write(dt.now().strftime('%Y-%m-%d %H:%M:%S') + '\n')
    for i in range(100):
        file.write('{:3d}위 {} - {}\n'.format(i+1, genie[i][0], genie[i][1]))
print('genieTop100.txt 파일로 쓰기 완료')
# Out:
# genieTop100.txt 파일로 쓰기 완료

# %%
try:
    file = open('./output/genieTop100.txt', 'r', -1, 'utf-8')
    lines = file.readlines()
    for line in lines:
        print(line.rstrip())
except FileNotFoundError:
    print('디스크에 파일이 없습니다.')
# Out:
# 2023-08-24 10:43:37
#   1위 ['NewJeans'] - ETA
#   2위 ['정국'] - Seven (Feat. Latto) (Clean Ver.)
#   3위 ['NewJeans'] - Super Shy
#   4위 ['박재정'] - 헤어지자 말해요
#   5위 ['IVE (아이브)'] - I AM
#   6위 ['(여자)아이들'] - 퀸카 (Queencard)
#   7위 ['NewJeans'] - Hype boy
#   8위 ['우디 (Woody)'] - 사막에서 꽃을 피우듯
#   9위 ['aespa'] - Spicy
#  10위 ['LE SSERAFIM (르세라핌)'] - 이브, 프시케 그리고 푸른 수염의 아내
#  11위 ['임영웅'] - 사랑은 늘 도망가
#  12위 ['IVE (아이브)'] - Kitsch
#  13위 ['AKMU (악뮤)'] - Love Lee
#  14위 ['임영웅'] - 우리들의 블루스
#  15위 ['임영웅'] - 모래 알갱이
#  16위 ['Paul Blanco'] - Summer (Feat. BE'O (비오))
#  17위 ['임영웅'] - 다시 만날 수 있을까
#  18위 ['전소미'] - Fast Forward
#  19위 ['임영웅'] - 이제 나만 믿어요
#  20위 ['임영웅'] - 무지개
#  21위 ['NewJeans'] - Ditto
#  22위 ['임영웅'] - London Boy
#  23위 ['임영웅'] - Polaroid
#  24위 ['임영웅'] - 아버지
#  25위 ['윤하 (YOUNHA)'] - 사건의 지평선
#  26위 ['임영웅'] - A bientot
#  27위 ['임영웅'] - 손이 참 곱던 그대
#  28위 ['임영웅'] - 사랑해 진짜
#  29위 ['Lauv'] - Steal The Show
#  30위 ['임영웅'] - 연애편지
#  31위 ['임영웅'] - 보금자리
#  32위 ['임영웅'] - 인생찬가
# ...
